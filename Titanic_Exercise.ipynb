# %% [markdown]
# <a href="https://colab.research.google.com/github/benitoredin0/BootCamp-2/blob/main/Titanic_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EJERCICIO TITANIC
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/RMS_Titanic_3.jpg/800px-RMS_Titanic_3.jpg)
#
# Para el ejercicio final, intentá combinar todas las habilidades que aprendiste hasta ahora para cumplir las consignas. **Sentite libre de desviarte de las consignas y explorar los datos que te parezcan interesantes.**
#
# **Link dataset**: https://raw.githubusercontent.com/riverofacundo/cursos/main/rain.csv
#
# Este archivo contiene información sobre todos los pasajeros y tripulantes del RMS Titanic. Sus columnas son:
#
# - ``name``: strings with the name of the passenger.
# - ``gender``: "male" or "female".
# - ``age``: a float with the persons age on the day of the sinking. The age of babies (under 12 months) is given as a fraction of one year.
# - ``class``: a string specifying the class (1st, 2nd or 3rd) for passengers or the type of service aboard for crew members.
# - ``embarked``: the persons place of of embarkment.
# - ``country``: the persons home country.
# - ``ticketno``: the persons ticket number (NA for crew members).
# - ``fare``: the ticket price (NA for crew members, musicians and employees of the shipyard company).
# - ``sibsp``: a number specifying the number if siblings/spouses aboard.
# - ``parch``: a number specifying the number of parents/children aboard.
# - ``survived``: a string ("no" or "yes") specifying whether the person has survived the sinking.

# %%
import pandas as pd
df = pd.read_csv('titanic.csv')
pd.options.display.max_colwidth = 150
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male  27.0      0
# 887                         Graham, Miss. Margaret Edith  female  19.0      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                                Behr, Mr. Karl Howell    male  26.0      0
# 890                                  Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.columns = df.columns.str.title()
print(df)
# Out:
#      Passengerid  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  Sibsp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male  27.0      0
# 887                         Graham, Miss. Margaret Edith  female  19.0      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                                Behr, Mr. Karl Howell    male  26.0      0
# 890                                  Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Passengerid      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# Sibsp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Ticket'] = df['Ticket'].apply(lambda x: re.sub(r'[^\d.]', '', x))
print(df.head())
# Out:
#    Passengerid  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  Sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0     521171   7.2500   NaN        S
# 1      0      17599  71.2833   C85        C
# 2      0  2.3101282   7.9250   NaN        S
# 3      0     113803  53.1000  C123        S
# 4      0     373450   8.0500   NaN        S

# %%
df = df.dropna(subset=['Age'])

df = df.dropna(subset=['Embarked'])

df = df.dropna(subset=['Ticket'])

df = df.dropna(subset=['Fare'])

df = df.dropna(subset=['Sibsp'])

df = df.dropna(subset=['Parch'])

df = df.dropna(subset=['Survived'])

df = df.dropna(subset=['Cabin'])

print(df)
# Out:
#      Passengerid  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                     Name     Sex   Age  Sibsp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                                McCarthy, Mr. Timothy J    male  54.0      0
# 10                       Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                              Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                   ...     ...   ...    ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                             Carlsson, Mr. Frans Olof    male  33.0      0
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                         Graham, Miss. Margaret Edith  female  19.0      0
# 889                                Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch  Ticket     Fare        Cabin Embarked
# 1        0   17599  71.2833          C85        C
# 3        0  113803  53.1000         C123        S
# 6        0   17463  51.8625          E46        S
# 10       1    9549  16.7000           G6        S
# 11       0  113783  26.5500         C103        S
# ..     ...     ...      ...          ...      ...
# 871      1   11751  52.5542          D35        S
# 872      0     695   5.0000  B51 B53 B55        S
# 879      1   11767  83.1583          C50        C
# 887      0  112053  30.0000          B42        S
# 889      0  111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Passengerid    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Sibsp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
import re

borrar = ["Mr\.", "Mrs\.", "Miss\.", "Master\.", "Don\.",r'\(.*?\)']
df.Name = df.Name.replace(regex=borrar, value='')

# %%
df['Survived'] = df['Survived'].replace([1, 0], ['yes', 'no'])

# %% [markdown]
# Leer el dataset y mostrar:
#
# - Los primeros 5 registros
# - Los ultimos 5 registros

# %%
df.head()
# Out:
#     Passengerid Survived  Pclass                        Name     Sex   Age  \
# 1             2      yes       1     Cumings,  John Bradley   female  38.0
# 3             4      yes       1   Futrelle,  Jacques Heath   female  35.0
# 6             7       no       1        McCarthy,  Timothy J    male  54.0
# 10           11      yes       3  Sandstrom,  Marguerite Rut  female   4.0
# 11           12      yes       1         Bonnell,  Elizabeth  female  58.0
#
#     Sibsp  Parch  Ticket     Fare Cabin Embarked
# 1       1      0   17599  71.2833   C85        C
# 3       1      0  113803  53.1000  C123        S
# 6       0      0   17463  51.8625   E46        S
# 10      1      1    9549  16.7000    G6        S
# 11      0      0  113783  26.5500  C103        S

# %%
df.tail()
# Out:
#      Passengerid Survived  Pclass                         Name     Sex   Age  \
# 871          872      yes       1  Beckwith,  Richard Leonard   female  47.0
# 872          873       no       1        Carlsson,  Frans Olof    male  33.0
# 879          880      yes       1          Potter,  Thomas Jr   female  56.0
# 887          888      yes       1      Graham,  Margaret Edith  female  19.0
# 889          890      yes       1           Behr,  Karl Howell    male  26.0
#
#      Sibsp  Parch  Ticket     Fare        Cabin Embarked
# 871      1      1   11751  52.5542          D35        S
# 872      0      0     695   5.0000  B51 B53 B55        S
# 879      0      1   11767  83.1583          C50        C
# 887      0      0  112053  30.0000          B42        S
# 889      0      0  111369  30.0000         C148        C

# %% [markdown]
# ¿Cuantas filas y columnas tiene el dataset?

# %%
df.shape
# Out:
# (183, 12)

# %% [markdown]
# Cambiar el nombre de la columna ``age`` por ``edad``

# %%
columnas = list(df.columns)

# %%
df.columns[5]
# Out:
# 'Age'

# %%
df.rename(columns={'Age':'Edad'},inplace=True)

# %%
df.columns
# Out:
# Index(['Passengerid', 'Survived', 'Pclass', 'Name', 'Sex', 'Edad', 'Sibsp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Aplicar un ``describe`` y sacar por lo menos 3 conclusiones

# %%
df.describe()
# Out:
#        Passengerid      Pclass        Edad       Sibsp       Parch        Fare
# count   183.000000  183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    1.191257   35.674426    0.464481    0.475410   78.682469
# std     247.052476    0.515187   15.643866    0.644159    0.754617   76.347843
# min       2.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%     263.500000    1.000000   24.000000    0.000000    0.000000   29.700000
# 50%     457.000000    1.000000   36.000000    0.000000    0.000000   57.000000
# 75%     676.000000    1.000000   47.500000    1.000000    1.000000   90.000000
# max     890.000000    3.000000   80.000000    3.000000    4.000000  512.329200

# %% [markdown]
# ¿Cuales son las personas que tienen los tickets con mayores precio?

# %%
df.loc[df['Fare'] == df['Fare'].max()]
# Out:
#      Passengerid Survived  Pclass                             Name   Sex  \
# 679          680      yes       1  Cardeza,  Thomas Drake Martinez  male
# 737          738      yes       1              Lesurer,  Gustave J  male
#
#      Edad  Sibsp  Parch Ticket      Fare        Cabin Embarked
# 679  36.0      0      1  17755  512.3292  B51 B53 B55        C
# 737  35.0      0      0  17755  512.3292         B101        C

# %% [markdown]
# Contar la cantidad de personas por genero

# %%
df['Sex'].value_counts()
# Out:
# male      95
# female    88
# Name: Sex, dtype: int64

# %% [markdown]
# ¿De cuantos paises diferentes provenian las personas?

# %%
import random
countries = ['Francia', 'Usa', 'Nueva Zelanda', 'Irlanda', 'Inglaterra']
df['Country'] = [random.choice(countries) for i in range(len(df))]

# %%
print(df['Country'].value_counts())
# Out:
# Usa              42
# Irlanda          41
# Inglaterra       36
# Nueva Zelanda    35
# Francia          29
# Name: Country, dtype: int64

# %%
print('Embarques:')
print(f'Inglaterra: {df[df["Embarked"] == "S"].shape[0]}')
print(f'Francia: {df[df["Embarked"] == "C"].shape[0]}')
print(f'Nueva Zelanda: {df[df["Embarked"] == "Q"].shape[0]}')
# Out:
# Embarques:
# Inglaterra: 116
# Francia: 65
# Nueva Zelanda: 2

# %% [markdown]
# Encontrar la edad promedio de todas las personas a bordo

# %%
print('La edad promedio de las personas a bordo',round(df['Edad'].mean(),1))
# Out:
# La edad promedio de las personas a bordo 35.7

# %% [markdown]
#  Filtrar solo los hombres, de primera clase, que sean de Estados unidos o Inglaterra. Finalmente ordenarlos por el precio del ticket

# %%
# Está hecho solo con Southampton ya que solo hay embarcación
df_filtrado = df[
    (df['Sex'] == 'male') &
    (df['Embarked'] == 'S') &
    (df['Pclass']==1)
]
df_filtrado = df_filtrado[['Passengerid','Name','Sex','Pclass','Embarked']]
df_filtrado.head()
# Out:
#     Passengerid                         Name   Sex  Pclass Embarked
# 6             7         McCarthy,  Timothy J  male       1        S
# 23           24    Sloper,  William Thompson  male       1        S
# 27           28  Fortune,  Charles Alexander  male       1        S
# 62           63     Harris,  Henry Birkhardt  male       1        S
# 92           93     Chaffee,  Herbert Fuller  male       1        S

# %% [markdown]
# Contar cuantas personas murieron o sobrevivieron que no sean ni de Estados unidos ni de Inglaterra

# %%
sobrevivientes = df[~df['Country'].isin(['Usa', 'England']) & (df['Survived'] == 'yes')].shape[0]
muertos = df[~df['Country'].isin(['Usa', 'England']) & (df['Survived'] == 'no')].shape[0]

print(f'Sobrevivientes(No USA ni Inglaterra): {sobrevivientes}')
print(f'Muertos(No USA ni Inglaterra): {muertos}')
# Out:
# Sobrevivientes(No USA ni Inglaterra): 96
# Muertos(No USA ni Inglaterra): 45

# %% [markdown]
# Encontrar la edad promedio de los hombres a bordo

# %%
print('La edad promedio de los hombres a bordo',round(df[df['Sex'] == 'male']['Edad'].mean(),1))
# Out:
# La edad promedio de los hombres a bordo 38.5

# %% [markdown]
# Seleccionar solo las personas que pertenezca a la clase '3rd', luego contar cuantos sobrevivieron y cuantos murieron.

# %%
df_filtrado = df[(df['Pclass']==3)]
df_filtrado = df_filtrado['Survived']

df_filtrado.value_counts()
# Out:
# yes    5
# no     5
# Name: Survived, dtype: int64

# %% [markdown]
# Tarifa promedio correspondiente a cada tipo de clase

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    88.683228
# 2    18.444447
# 3    11.027500
# Name: Fare, dtype: float64

# %% [markdown]
# Encuentre la tasa de supervivencia promedio correspondiente a cada tipo de cabina

# %%
df['Survived'] = df['Survived'].replace(['yes', 'no'], [1, 0])
(df.groupby('Cabin')['Survived'].mean()).head()
# Out:
# Cabin
# A10    0.0
# A16    1.0
# A20    1.0
# A23    1.0
# A24    0.0
# Name: Survived, dtype: float64

# %%
df['Survived'] = df['Survived'].replace([1, 0], ['yes', 'no'])

# %% [markdown]
# Hacer graficos y sacar conclusiones, algunos ejemplos:
#
# - Relacion entre la clase en la que se viaja y la edad de la persona
# - Supervivencia por edad

# %%
from dataprep.eda import create_report
report=create_report(df)
report.save('Report')
# Out:
# Computing moment_chunk-fb3605f95986fb47039f3425ba0fd866:  20%|██        | 309/1510 [00:00<00:00, 1564.79it/s]/usr/local/lib/python3.10/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /root/.local/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /root/.local/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /root/.local/lib/python3.10/site-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# Report has been saved to Report.html!
